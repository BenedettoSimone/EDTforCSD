# %% [markdown]
# # Decision tree classifier

# %%
from statistics import mean
import shutil
import os
import pandas as pd
from sklearn import tree
import matplotlib.pyplot as plt
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score

#to store mean of results for each smell
results = []

path = 'images_decision_tree'
# Check whether the specified path exists or not
isExist = os.path.exists(path)
if isExist:
    shutil.rmtree(path)

os.mkdir(path)

#######################

os.chdir('datasets/stratifiedKfold')

#folder smell
for i in os.listdir():
    if '.DS_Store' not in i:
        os.chdir(i)
        print("\n===================== "+i+" =====================")

        path = '../../../images_decision_tree/'+i
        # Check whether the specified path exists or not
        isExist = os.path.exists(path)
        if isExist:
            shutil.rmtree(path)

        os.mkdir(path)

        f_measure_smell = []
        f_measure_not_smell = []

        for fold in os.listdir():
            if '.DS_Store' not in fold:
                os.chdir(fold)

                train_set_over = pd.read_csv("train_set_oversampled.csv")
                test_set = pd.read_csv("test_set.csv")

                #split data and label
                X_train = train_set_over.iloc[:, :-1]
                y_train = train_set_over.iloc[:, -1:]

                X_test = test_set.iloc[:, 1:-1]
                y_test = test_set.iloc[:, -1:]

                features_name = X_train.columns.values.tolist()
                class_name = y_train.columns.values.tolist()

                print("\n\t----------------- "+fold+" -----------------\n")

                #nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split samples.
                classifier = DecisionTreeClassifier()
                print("\tTrain size:",len(X_train), ", Test size:", len(X_test))

                decision_tree = classifier.fit(X_train, y_train)


                acc_score = classifier.score(X_test, y_test)
                print("\n\tAccuracy:", acc_score)

                y_pred = classifier.predict(X_test)
                y_pred = pd.DataFrame(y_pred, columns = [class_name[0]])
                y_pred.to_csv('pred_set.csv', index=False)


                print("\tCorrect labels:", accuracy_score(y_pred, y_test, normalize=False), "of", len(X_test))

                per_class_precision = precision_score(y_pred, y_test, average=None)
                print('\n\tPrecision score:', per_class_precision)

                recall = recall_score(y_pred, y_test, average=None)
                print('\tRecall score:', recall)

                F_measure = f1_score(y_pred, y_test, average=None)
                print('\tF-Measure:', F_measure)
                f_measure_not_smell.append(F_measure[0])
                f_measure_smell.append(F_measure[1])

                #save image
                fig = plt.figure(figsize=(100,100))
                fig1 = tree.plot_tree(decision_tree,
                       feature_names=features_name,
                       class_names=['Not' + class_name[0], class_name[0]],
                       filled=True)
                plt.close(fig)
                fig.savefig('../'+path+ '/'+class_name[0]+"_"+fold+".png")

                os.chdir('..')
        os.chdir('..')

        results.append([i,'['+str(mean(f_measure_not_smell))+', '+str(mean(f_measure_smell))+']'])
os.chdir('..')
# Out:
# ===================== LazyClass =====================
#
# 	----------------- 9 -----------------
#
# 	Train size: 132990 , Test size: 7391
#
# 	Accuracy: 0.9995941009335678
# 	Correct labels: 7388 of 7391
#
# 	Precision score: [0.99959394 1.        ]
# 	Recall score: [1.  0.5]
# 	F-Measure: [0.99979693 0.66666667]
#
# 	----------------- 7 -----------------
#
# 	Train size: 132990 , Test size: 7391
#
# 	Accuracy: 1.0
# 	Correct labels: 7391 of 7391
#
# 	Precision score: [1. 1.]
# 	Recall score: [1. 1.]
# 	F-Measure: [1. 1.]
#
# 	----------------- 6 -----------------
#
# 	Train size: 132990 , Test size: 7391
#
# 	Accuracy: 1.0
# 	Correct labels: 7391 of 7391
#
# 	Precision score: [1. 1.]
# 	Recall score: [1. 1.]
# 	F-Measure: [1. 1.]
#
# 	----------------- 1 -----------------
#
# 	Train size: 132988 , Test size: 7391
#
# 	Accuracy: 0.9995941009335678
# 	Correct labels: 7388 of 7391
#
# 	Precision score: [0.99986466 0.        ]
# 	Recall score: [0.99972936 0.        ]
# 	F-Measure: [0.99979701 0.        ]
#
# 	----------------- 10 -----------------
#
# 	Train size: 132990 , Test size: 7391
#
# 	Accuracy: 0.9982411040454607
# 	Correct labels: 7378 of 7391
#
# 	Precision score: [0.99824039 1.        ]
# 	Recall score: [1.     0.1875]
# 	F-Measure: [0.99911942 0.31578947]
#
# 	----------------- 8 -----------------
#
# 	Train size: 132990 , Test size: 7391
#
# 	Accuracy: 0.9952645108916249
# 	Correct labels: 7356 of 7391
#
# 	Precision score: [0.99526259 1.        ]
# 	Recall score: [1.         0.07894737]
# 	F-Measure: [0.99762567 0.14634146]
#
# 	----------------- 4 -----------------
#
# 	Train size: 132990 , Test size: 7391
#
# 	Accuracy: 1.0
# 	Correct labels: 7391 of 7391
#
# 	Precision score: [1. 1.]
# 	Recall score: [1. 1.]
# 	F-Measure: [1. 1.]
#
# 	----------------- 3 -----------------
#
# 	Train size: 132988 , Test size: 7391
#
# 	Accuracy: 0.9998647003111892
# 	Correct labels: 7390 of 7391
#
# 	Precision score: [0.99986466 1.        ]
# 	Recall score: [1.         0.66666667]
# 	F-Measure: [0.99993233 0.8       ]
#
# 	----------------- 2 -----------------
#
# 	Train size: 132988 , Test size: 7391
#
# 	Accuracy: 0.9997294006223786
# 	Correct labels: 7389 of 7391
#
# 	Precision score: [0.99972933 1.        ]
# 	Recall score: [1.  0.5]
# 	F-Measure: [0.99986465 0.66666667]
#
# 	----------------- 5 -----------------
#
# 	Train size: 132990 , Test size: 7391
#
# 	Accuracy: 1.0
# 	Correct labels: 7391 of 7391
#
# 	Precision score: [1. 1.]
# 	Recall score: [1. 1.]
# 	F-Measure: [1. 1.]
# ===================== SpaghettiCode =====================
#
# 	----------------- 9 -----------------
#
# 	Train size: 132320 , Test size: 7391
#
# 	Accuracy: 0.9967528074685428
# 	Correct labels: 7367 of 7391
#
# 	Precision score: [0.99673514 1.        ]
# 	Recall score: [1.    0.625]
# 	F-Measure: [0.9983649  0.76923077]
#
# 	----------------- 7 -----------------
#
# 	Train size: 132320 , Test size: 7391
#
# 	Accuracy: 0.9956704099580571
# 	Correct labels: 7359 of 7391
#
# 	Precision score: [0.99945586 0.3       ]
# 	Recall score: [0.99620339 0.75      ]
# 	F-Measure: [0.99782697 0.42857143]
#
# 	----------------- 6 -----------------
#
# 	Train size: 132320 , Test size: 7391
#
# 	Accuracy: 0.9991882018671358
# 	Correct labels: 7385 of 7391
#
# 	Precision score: [0.99945586 0.95      ]
# 	Recall score: [0.99972785 0.9047619 ]
# 	F-Measure: [0.99959184 0.92682927]
#
# 	----------------- 1 -----------------
#
# 	Train size: 132318 , Test size: 7391
#
# 	Accuracy: 0.9798403463672034
# 	Correct labels: 7242 of 7391
#
# 	Precision score: [0.98014146 0.92307692]
# 	Recall score: [0.99958385 0.1978022 ]
# 	F-Measure: [0.98976719 0.32579186]
#
# 	----------------- 10 -----------------
#
# 	Train size: 132320 , Test size: 7391
#
# 	Accuracy: 0.9886348261398998
# 	Correct labels: 7307 of 7391
#
# 	Precision score: [0.98952523 0.825     ]
# 	Recall score: [0.99903859 0.3       ]
# 	F-Measure: [0.99425916 0.44      ]
#
# 	----------------- 8 -----------------
#
# 	Train size: 132320 , Test size: 7391
#
# 	Accuracy: 0.9806521445000677
# 	Correct labels: 7248 of 7391
#
# 	Precision score: [0.98136308 0.85      ]
# 	Recall score: [0.99916898 0.19883041]
# 	F-Measure: [0.99018599 0.32227488]
#
# 	----------------- 4 -----------------
#
# 	Train size: 132320 , Test size: 7391
#
# 	Accuracy: 0.9964822080909214
# 	Correct labels: 7365 of 7391
#
# 	Precision score: [0.99687117 0.925     ]
# 	Recall score: [0.99959078 0.61666667]
# 	F-Measure: [0.99822912 0.74      ]
#
# 	----------------- 3 -----------------
#
# 	Train size: 132320 , Test size: 7391
#
# 	Accuracy: 0.9956704099580571
# 	Correct labels: 7359 of 7391
#
# 	Precision score: [0.99591892 0.95      ]
# 	Recall score: [0.99972689 0.55882353]
# 	F-Measure: [0.99781927 0.7037037 ]
#
# 	----------------- 2 -----------------
#
# 	Train size: 132320 , Test size: 7391
#
# 	Accuracy: 0.9948586118251928
# 	Correct labels: 7353 of 7391
#
# 	Precision score: [0.99551081 0.875     ]
# 	Recall score: [0.99931722 0.51470588]
# 	F-Measure: [0.99741039 0.64814815]
#
# 	----------------- 5 -----------------
#
# 	Train size: 132320 , Test size: 7391
#
# 	Accuracy: 0.9964822080909214
# 	Correct labels: 7365 of 7391
#
# 	Precision score: [0.99741532 0.825     ]
# 	Recall score: [0.99904619 0.63461538]
# 	F-Measure: [0.99823009 0.7173913 ]
# ===================== RefusedBequest =====================
#
# 	----------------- 9 -----------------
#
# 	Train size: 132760 , Test size: 7391
#
# 	Accuracy: 0.9989176024895142
# 	Correct labels: 7383 of 7391
#
# 	Precision score: [0.99959322 0.6875    ]
# 	Recall score: [0.99932222 0.78571429]
# 	F-Measure: [0.9994577  0.73333333]
#
# 	----------------- 7 -----------------
#
# 	Train size: 132760 , Test size: 7391
#
# 	Accuracy: 0.999052902178325
# 	Correct labels: 7384 of 7391
#
# 	Precision score: [0.99918644 0.9375    ]
# 	Recall score: [0.99986431 0.71428571]
# 	F-Measure: [0.99952526 0.81081081]
#
# 	----------------- 6 -----------------
#
# 	Train size: 132760 , Test size: 7391
#
# 	Accuracy: 0.9997294006223786
# 	Correct labels: 7389 of 7391
#
# 	Precision score: [0.99972881 1.        ]
# 	Recall score: [1.         0.88888889]
# 	F-Measure: [0.99986439 0.94117647]
#
# 	----------------- 1 -----------------
#
# 	Train size: 132758 , Test size: 7391
#
# 	Accuracy: 0.9914761196049249
# 	Correct labels: 7328 of 7391
#
# 	Precision score: [0.99186551 0.8       ]
# 	Recall score: [0.99959011 0.16666667]
# 	F-Measure: [0.99571283 0.27586207]
#
# 	----------------- 10 -----------------
#
# 	Train size: 132760 , Test size: 7391
#
# 	Accuracy: 0.9982411040454607
# 	Correct labels: 7378 of 7391
#
# 	Precision score: [0.99864407 0.8125    ]
# 	Recall score: [0.99959283 0.56521739]
# 	F-Measure: [0.99911823 0.66666667]
#
# 	----------------- 8 -----------------
#
# 	Train size: 132760 , Test size: 7391
#
# 	Accuracy: 0.9889054255175214
# 	Correct labels: 7309 of 7391
#
# 	Precision score: [0.98888136 1.        ]
# 	Recall score: [1.         0.16326531]
# 	F-Measure: [0.9944096  0.28070175]
#
# 	----------------- 4 -----------------
#
# 	Train size: 132758 , Test size: 7391
#
# 	Accuracy: 1.0
# 	Correct labels: 7391 of 7391
#
# 	Precision score: [1. 1.]
# 	Recall score: [1. 1.]
# 	F-Measure: [1. 1.]
#
# 	----------------- 3 -----------------
#
# 	Train size: 132758 , Test size: 7391
#
# 	Accuracy: 0.9997294006223786
# 	Correct labels: 7389 of 7391
#
# 	Precision score: [0.99986443 0.93333333]
# 	Recall score: [0.99986443 0.93333333]
# 	F-Measure: [0.99986443 0.93333333]
#
# 	----------------- 2 -----------------
#
# 	Train size: 132758 , Test size: 7391
#
# 	Accuracy: 0.99810580435665
# 	Correct labels: 7377 of 7391
#
# 	Precision score: [0.99810195 1.        ]
# 	Recall score: [1.         0.51724138]
# 	F-Measure: [0.99905007 0.68181818]
#
# 	----------------- 5 -----------------
#
# 	Train size: 132758 , Test size: 7391
#
# 	Accuracy: 0.9997294006223786
# 	Correct labels: 7389 of 7391
#
# 	Precision score: [1.         0.86666667]
# 	Recall score: [0.99972892 1.        ]
# 	F-Measure: [0.99986444 0.92857143]
# ===================== LargeClass =====================
#
# 	----------------- 9 -----------------
#
# 	Train size: 132882 , Test size: 7391
#
# 	Accuracy: 1.0
# 	Correct labels: 7391 of 7391
#
# 	Precision score: [1. 1.]
# 	Recall score: [1. 1.]
# 	F-Measure: [1. 1.]
#
# 	----------------- 7 -----------------
#
# 	Train size: 132882 , Test size: 7391
#
# 	Accuracy: 1.0
# 	Correct labels: 7391 of 7391
#
# 	Precision score: [1. 1.]
# 	Recall score: [1. 1.]
# 	F-Measure: [1. 1.]
#
# 	----------------- 6 -----------------
#
# 	Train size: 132882 , Test size: 7391
#
# 	Accuracy: 0.9998647003111892
# 	Correct labels: 7390 of 7391
#
# 	Precision score: [1.         0.88888889]
# 	Recall score: [0.99986455 1.        ]
# 	F-Measure: [0.99993227 0.94117647]
#
# 	----------------- 1 -----------------
#
# 	Train size: 132880 , Test size: 7391
#
# 	Accuracy: 0.9979705046678392
# 	Correct labels: 7376 of 7391
#
# 	Precision score: [0.9982392 0.75     ]
# 	Recall score: [0.9997287  0.31578947]
# 	F-Measure: [0.9989834  0.44444444]
#
# 	----------------- 10 -----------------
#
# 	Train size: 132882 , Test size: 7391
#
# 	Accuracy: 0.9968881071573535
# 	Correct labels: 7368 of 7391
#
# 	Precision score: [0.99701978 0.88888889]
# 	Recall score: [0.99986415 0.26666667]
# 	F-Measure: [0.99843994 0.41025641]
#
# 	----------------- 8 -----------------
#
# 	Train size: 132882 , Test size: 7391
#
# 	Accuracy: 0.9889054255175214
# 	Correct labels: 7309 of 7391
#
# 	Precision score: [0.9888919 1.       ]
# 	Recall score: [1.        0.0989011]
# 	F-Measure: [0.99441493 0.18      ]
#
# 	----------------- 4 -----------------
#
# 	Train size: 132882 , Test size: 7391
#
# 	Accuracy: 0.9995941009335678
# 	Correct labels: 7388 of 7391
#
# 	Precision score: [1.         0.66666667]
# 	Recall score: [0.99959377 1.        ]
# 	F-Measure: [0.99979684 0.8       ]
#
# 	----------------- 3 -----------------
#
# 	Train size: 132880 , Test size: 7391
#
# 	Accuracy: 0.9995941009335678
# 	Correct labels: 7388 of 7391
#
# 	Precision score: [0.99972911 0.875     ]
# 	Recall score: [0.99986454 0.77777778]
# 	F-Measure: [0.99979682 0.82352941]
#
# 	----------------- 2 -----------------
#
# 	Train size: 132880 , Test size: 7391
#
# 	Accuracy: 0.9993235015559464
# 	Correct labels: 7386 of 7391
#
# 	Precision score: [1.    0.375]
# 	Recall score: [0.99932323 1.        ]
# 	F-Measure: [0.9996615  0.54545455]
#
# 	----------------- 5 -----------------
#
# 	Train size: 132882 , Test size: 7391
#
# 	Accuracy: 0.9994588012447572
# 	Correct labels: 7387 of 7391
#
# 	Precision score: [1.         0.55555556]
# 	Recall score: [0.99945843 1.        ]
# 	F-Measure: [0.99972914 0.71428571]
# ===================== ComplexClass =====================
#
# 	----------------- 9 -----------------
#
# 	Train size: 132922 , Test size: 7391
#
# 	Accuracy: 1.0
# 	Correct labels: 7391 of 7391
#
# 	Precision score: [1. 1.]
# 	Recall score: [1. 1.]
# 	F-Measure: [1. 1.]
#
# 	----------------- 7 -----------------
#
# 	Train size: 132922 , Test size: 7391
#
# 	Accuracy: 0.9998647003111892
# 	Correct labels: 7390 of 7391
#
# 	Precision score: [0.99986459 1.        ]
# 	Recall score: [1.         0.85714286]
# 	F-Measure: [0.99993229 0.92307692]
#
# 	----------------- 6 -----------------
#
# 	Train size: 132922 , Test size: 7391
#
# 	Accuracy: 0.9997294006223786
# 	Correct labels: 7389 of 7391
#
# 	Precision score: [1.         0.66666667]
# 	Recall score: [0.99972925 1.        ]
# 	F-Measure: [0.99986461 0.8       ]
#
# 	----------------- 1 -----------------
#
# 	Train size: 132924 , Test size: 7391
#
# 	Accuracy: 0.9993235015559464
# 	Correct labels: 7386 of 7391
#
# 	Precision score: [0.99945829 0.85714286]
# 	Recall score: [0.99986452 0.6       ]
# 	F-Measure: [0.99966136 0.70588235]
#
# 	----------------- 10 -----------------
#
# 	Train size: 132922 , Test size: 7391
#
# 	Accuracy: 0.9975646056014071
# 	Correct labels: 7373 of 7391
#
# 	Precision score: [0.99823968 0.16666667]
# 	Recall score: [0.99932222 0.07142857]
# 	F-Measure: [0.99878065 0.1       ]
#
# 	----------------- 8 -----------------
#
# 	Train size: 132922 , Test size: 7391
#
# 	Accuracy: 0.9898525233391963
# 	Correct labels: 7316 of 7391
#
# 	Precision score: [0.98984428 1.        ]
# 	Recall score: [1.         0.07407407]
# 	F-Measure: [0.99489622 0.13793103]
#
# 	----------------- 4 -----------------
#
# 	Train size: 132924 , Test size: 7391
#
# 	Accuracy: 1.0
# 	Correct labels: 7391 of 7391
#
# 	Precision score: [1. 1.]
# 	Recall score: [1. 1.]
# 	F-Measure: [1. 1.]
#
# 	----------------- 3 -----------------
#
# 	Train size: 132924 , Test size: 7391
#
# 	Accuracy: 0.999052902178325
# 	Correct labels: 7384 of 7391
#
# 	Precision score: [0.999052 1.      ]
# 	Recall score: [1.  0.5]
# 	F-Measure: [0.99952578 0.66666667]
#
# 	----------------- 2 -----------------
#
# 	Train size: 132924 , Test size: 7391
#
# 	Accuracy: 0.9993235015559464
# 	Correct labels: 7386 of 7391
#
# 	Precision score: [0.99945829 0.85714286]
# 	Recall score: [0.99986452 0.6       ]
# 	F-Measure: [0.99966136 0.70588235]
#
# 	----------------- 5 -----------------
#
# 	Train size: 132922 , Test size: 7391
#
# 	Accuracy: 0.9993235015559464
# 	Correct labels: 7386 of 7391
#
# 	Precision score: [0.99972918 0.5       ]
# 	Recall score: [0.99959383 0.6       ]
# 	F-Measure: [0.9996615  0.54545455]

# %%
for result in results:
    print(result[0]+": "+result[1])
# Out:
# LazyClass: [0.9996135998804423, 0.6595464270432178]
# SpaghettiCode: [0.9961684909969379, 0.6021941359014766]
# RefusedBequest: [0.9986866947402058, 0.7252274048473473]
# LargeClass: [0.9990754839258026, 0.6859146996794055]
# ComplexClass: [0.9991983774485352, 0.6584893875563247]
